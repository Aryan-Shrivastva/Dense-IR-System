# %% [markdown]
# # Dense IR exploration
#
# Use this notebook to prototype queries, inspect embeddings, or call the local API after `uvicorn api.main:app`.
#
# ```python
# # Example: health check
# import httpx
# r = httpx.get("http://127.0.0.1:8000/api/health")
# r.json()
# ```
